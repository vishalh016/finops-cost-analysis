# %%
from pyspark.sql.types import StructType, StructField, StringType, DoubleType
print("Import successful")

# %%
FOCUS_SCHEMA = StructType([
    StructField("BilledCost", DoubleType(), True),
    StructField("BillingAccountId", StringType(), True),
    StructField("BillingAccountName", StringType(), True),
    StructField("BillingAccountType", StringType(), True),
    StructField("BillingCurrency", StringType(), True),
    StructField("BillingPeriodEnd", StringType(), True),
    StructField("BillingPeriodStart", StringType(), True),
    StructField("ChargeCategory", StringType(), True),
    StructField("ChargeClass", StringType(), True),
    StructField("ChargeDescription", StringType(), True),
    StructField("ChargeFrequency", StringType(), True),
    StructField("ChargePeriodEnd", StringType(), True),
    StructField("ChargePeriodStart", StringType(), True),
    StructField("CommitmentDiscountCategory", StringType(), True),
    StructField("CommitmentDiscountId", StringType(), True),
    StructField("CommitmentDiscountName", StringType(), True),
    StructField("CommitmentDiscountStatus", StringType(), True),
    StructField("CommitmentDiscountType", StringType(), True),
    StructField("ConsumedQuantity", DoubleType(), True),
    StructField("ConsumedUnit", StringType(), True),
    StructField("ContractedCost", DoubleType(), True),
    StructField("ContractedUnitPrice", DoubleType(), True),
    StructField("EffectiveCost", DoubleType(), True),
    StructField("InvoiceIssuerName", StringType(), True),
    StructField("ListCost", DoubleType(), True),
    StructField("ListUnitPrice", DoubleType(), True),
    StructField("PricingCategory", StringType(), True),
    StructField("PricingQuantity", DoubleType(), True),
    StructField("PricingUnit", StringType(), True),
    StructField("ProviderName", StringType(), True),
    StructField("PublisherName", StringType(), True),
    StructField("RegionId", StringType(), True),
    StructField("RegionName", StringType(), True),
    StructField("ResourceId", StringType(), True),
    StructField("ResourceName", StringType(), True),
    StructField("ResourceType", StringType(), True),
    StructField("ServiceCategory", StringType(), True),
    StructField("ServiceName", StringType(), True),
    StructField("SkuId", StringType(), True),
    StructField("SkuPriceId", StringType(), True),
    StructField("SubAccountId", StringType(), True),
    StructField("SubAccountName", StringType(), True),
    StructField("SubAccountType", StringType(), True),
    StructField("Tags", StringType(), True),
    StructField("x_AccountId", StringType(), True),
    StructField("x_AccountName", StringType(), True),
    StructField("x_AccountOwnerId", StringType(), True),
    StructField("x_BilledCostInUsd", DoubleType(), True),
    StructField("x_BilledUnitPrice", DoubleType(), True),
    StructField("x_BillingAccountId", StringType(), True),
    StructField("x_BillingAccountName", StringType(), True),
    StructField("x_BillingExchangeRate", DoubleType(), True),
    StructField("x_BillingExchangeRateDate", StringType(), True),
    StructField("x_BillingProfileId", StringType(), True),
    StructField("x_BillingProfileName", StringType(), True),
    StructField("x_ContractedCostInUsd", DoubleType(), True),
    StructField("x_CostAllocationRuleName", StringType(), True),
    StructField("x_CostCenter", StringType(), True),
    StructField("x_CustomerId", StringType(), True),
    StructField("x_CustomerName", StringType(), True),
    StructField("x_EffectiveCostInUsd", DoubleType(), True),
    StructField("x_EffectiveUnitPrice", DoubleType(), True),
    StructField("x_InvoiceId", StringType(), True),
    StructField("x_InvoiceIssuerId", StringType(), True),
    StructField("x_InvoiceSectionId", StringType(), True),
    StructField("x_InvoiceSectionName", StringType(), True),
    StructField("x_ListCostInUsd", DoubleType(), True),
    StructField("x_PartnerCreditApplied", StringType(), True),
    StructField("x_PartnerCreditRate", DoubleType(), True),
    StructField("x_PricingBlockSize", DoubleType(), True),
    StructField("x_PricingCurrency", StringType(), True),
    StructField("x_PricingSubcategory", StringType(), True),
    StructField("x_PricingUnitDescription", StringType(), True),
    StructField("x_PublisherCategory", StringType(), True),
    StructField("x_PublisherId", StringType(), True),
    StructField("x_ResellerId", StringType(), True),
    StructField("x_ResellerName", StringType(), True),
    StructField("x_ResourceGroupName", StringType(), True),
    StructField("x_ResourceType", StringType(), True),
    StructField("x_ServicePeriodEnd", StringType(), True),
    StructField("x_ServicePeriodStart", StringType(), True),
    StructField("x_SkuDescription", StringType(), True),
    StructField("x_SkuDetails", StringType(), True),
    StructField("x_SkuIsCreditEligible", StringType(), True),
    StructField("x_SkuMeterCategory", StringType(), True),
    StructField("x_SkuMeterId", StringType(), True),
    StructField("x_SkuMeterName", StringType(), True),
    StructField("x_SkuMeterSubcategory", StringType(), True),
    StructField("x_SkuOfferId", StringType(), True),
    StructField("x_SkuOrderId", StringType(), True),
    StructField("x_SkuOrderName", StringType(), True),
    StructField("x_SkuPartNumber", StringType(), True),
    StructField("x_SkuRegion", StringType(), True),
    StructField("x_SkuServiceFamily", StringType(), True),
    StructField("x_SkuTerm", StringType(), True),
    StructField("x_SkuTier", StringType(), True),
])

print(f"✅ FOCUS_SCHEMA — {len(FOCUS_SCHEMA.fields)} columns")

# %%
NON_FOCUS_SCHEMA = StructType([
    StructField("invoiceId", StringType(), True),
    StructField("previousInvoiceId", StringType(), True),
    StructField("billingAccountId", StringType(), True),
    StructField("billingAccountName", StringType(), True),
    StructField("billingProfileId", StringType(), True),
    StructField("billingProfileName", StringType(), True),
    StructField("invoiceSectionId", StringType(), True),
    StructField("invoiceSectionName", StringType(), True),
    StructField("resellerName", StringType(), True),
    StructField("resellerMpnId", StringType(), True),
    StructField("costCenter", StringType(), True),
    StructField("billingPeriodEndDate", StringType(), True),
    StructField("billingPeriodStartDate", StringType(), True),
    StructField("servicePeriodEndDate", StringType(), True),
    StructField("servicePeriodStartDate", StringType(), True),
    StructField("date", StringType(), True),
    StructField("serviceFamily", StringType(), True),
    StructField("productOrderId", StringType(), True),
    StructField("productOrderName", StringType(), True),
    StructField("consumedService", StringType(), True),
    StructField("meterId", StringType(), True),
    StructField("meterName", StringType(), True),
    StructField("meterCategory", StringType(), True),
    StructField("meterSubCategory", StringType(), True),
    StructField("meterRegion", StringType(), True),
    StructField("ProductId", StringType(), True),
    StructField("ProductName", StringType(), True),
    StructField("SubscriptionId", StringType(), True),
    StructField("subscriptionName", StringType(), True),
    StructField("publisherType", StringType(), True),
    StructField("publisherId", StringType(), True),
    StructField("publisherName", StringType(), True),
    StructField("resourceGroupName", StringType(), True),
    StructField("ResourceId", StringType(), True),
    StructField("resourceLocation", StringType(), True),
    StructField("location", StringType(), True),
    StructField("effectivePrice", DoubleType(), True),
    StructField("quantity", DoubleType(), True),
    StructField("unitOfMeasure", StringType(), True),
    StructField("chargeType", StringType(), True),
    StructField("billingCurrency", StringType(), True),
    StructField("pricingCurrency", StringType(), True),
    StructField("costInBillingCurrency", DoubleType(), True),
    StructField("costInPricingCurrency", DoubleType(), True),
    StructField("costInUsd", DoubleType(), True),
    StructField("paygCostInBillingCurrency", DoubleType(), True),
    StructField("paygCostInUsd", DoubleType(), True),
    StructField("exchangeRatePricingToBilling", DoubleType(), True),
    StructField("exchangeRateDate", StringType(), True),
    StructField("isAzureCreditEligible", StringType(), True),
    StructField("serviceInfo1", StringType(), True),
    StructField("serviceInfo2", StringType(), True),
    StructField("additionalInfo", StringType(), True),
    StructField("tags", StringType(), True),
    StructField("PayGPrice", DoubleType(), True),
    StructField("frequency", StringType(), True),
    StructField("term", StringType(), True),
    StructField("reservationId", StringType(), True),
    StructField("reservationName", StringType(), True),
    StructField("pricingModel", StringType(), True),
    StructField("unitPrice", DoubleType(), True),
    StructField("costAllocationRuleName", StringType(), True),
    StructField("benefitId", StringType(), True),
    StructField("benefitName", StringType(), True),
    StructField("provider", StringType(), True),
])

print(f"✅ NON_FOCUS_SCHEMA — {len(NON_FOCUS_SCHEMA.fields)} columns")

# %%
print(f"FOCUS 1.2 Actual Cost: {len(FOCUS_SCHEMA.fields)} columns")
print(f"NON-FOCUS Actual Cost: {len(NON_FOCUS_SCHEMA.fields)} columns")

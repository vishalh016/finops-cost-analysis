# %% [markdown]
# SOURCE & DESTINATION PATH DECLARATION

# %%
### SOURCE STORAGE ACCOUNT & CONTAINER DETAILS 
DATASOURCE_ADLS_ACCOUNT = "adbstoragev10"
DATASOURCE_CONTAINER = "finops-cost-usage-report"

### MEDALLION STORAGE ACCOUNT & CONTAINER DETAILS
MEDALLION_ADLS_ACCOUNT = "adbstoragev10"
BRONZE_CONTAINER = "bronze"
SILVER_CONTAINER = "silver"
GOLD_CONTAINER = "gold"

### SOURCE FILE PATH
SOURCE_PATH_FOCUS_DAILY = f"abfss://{DATASOURCE_ADLS_ACCOUNT}@{DATASOURCE_CONTAINER}.dfs.core.windows.net/cur/focus-cost"
SOURCE_PATH_FOCUS_MONTHLY = f"abfss://{DATASOURCE_ADLS_ACCOUNT}@{DATASOURCE_CONTAINER}.dfs.core.windows.net/cur/focus-cost-monthly"
SOURCE_PATH_NON_FOCUS = f"abfss://{DATASOURCE_ADLS_ACCOUNT}@{DATASOURCE_CONTAINER}.dfs.core.windows.net/cur/actual-cost"
SOURCE_PATH_NON_FOCUS_MONTHLY = f"abfss://{DATASOURCE_ADLS_ACCOUNT}@{DATASOURCE_CONTAINER}.dfs.core.windows.net/cur/actual-cost-monthly"

### BRONZE LAYER DETAILS
BRONZE_PATH_FOCUS = f"abfss://{MEDALLION_ADLS_ACCOUNT}@{BRONZE_CONTAINER}.dfs.core.windows.net/focus"
BRONZE_PATH_NON_FOCUS = f"abfss://{MEDALLION_ADLS_ACCOUNT}@{BRONZE_CONTAINER}.dfs.core.windows.net/non_focus"
BRONZE_PATH_FOCUS_CHECKPOINT = f"abfss://{MEDALLION_ADLS_ACCOUNT}@{BRONZE_CONTAINER}.dfs.core.windows.net/_checkpoints/focus"
BRONZE_PATH_NON_FOCUS_CHECKPOINT = f"abfss://{MEDALLION_ADLS_ACCOUNT}@{BRONZE_CONTAINER}.dfs.core.windows.net/_checkpoints/non_focus"

### SILVER LAYER DETAILS
SILVER_PATH_FOCUS = f"abfss://{MEDALLION_ADLS_ACCOUNT}@{SILVER_CONTAINER}.dfs.core.windows.net/focus"
SILVER_PATH_NON_FOCUS = f"abfss://{MEDALLION_ADLS_ACCOUNT}@{SILVER_CONTAINER}.dfs.core.windows.net/non_focus"

### GOLD LAYER DETAILS
GOLD_PATH_FOCUS = f"abfss://{MEDALLION_ADLS_ACCOUNT}@{GOLD_CONTAINER}.dfs.core.windows.net/focus"
GOLD_PATH_NON_FOCUS = f"abfss://{MEDALLION_ADLS_ACCOUNT}@{GOLD_CONTAINER}.dfs.core.windows.net/non_focus"
